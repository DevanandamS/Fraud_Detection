# %%
import pandas as pd
import sys
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import sklearn

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe().T
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.919560e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.688174e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.769071e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.782312e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552563e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.010663e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.694249e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.927028e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.137024e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.768627e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.170318e-16      1.020713   -4.797473     -0.762494
# ...

# %%
df_sample = df.sample(frac=0.9, random_state=1)

# %%
df_sample.shape
# Out:
# (256326, 31)

# %%
#Plot histogram
df_sample.hist(figsize=(20, 30))
plt.show()

# %%
fraud = df_sample[df_sample['Class'] == 1]
valid = df_sample[df_sample['Class'] == 0]

outlier_fraction  = float(len(fraud)/len(valid))

# %%
print("Fraud percentage: {}".format(outlier_fraction))
print("Fraud count: {}".format(len(fraud)))
print("valid count: {}".format(len(valid)))
# Out:
# Fraud percentage: 0.0017469194423926934
# Fraud count: 447
# valid count: 255879

# %%
#find correlation:
corrmat = df_sample.corr()
fig = plt.figure(figsize=(20, 10))
sns.heatmap(corrmat, vmax= .8, square=True)
plt.show()

# %%
X_columns = [c for c in df_sample.columns if c not in ['Class']]

# %%
X = df_sample[X_columns]
y = df_sample['Class']

# %%
X.shape
# Out:
# (256326, 30)

# %%
y.shape
# Out:
# (256326,)

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

# %%
#define random state
state = 1

# define the outlier detection methods

classifiers = {
    "Isolation forest": IsolationForest(max_samples=len(X), 
                                        contamination=outlier_fraction, 
                                        random_state=state),
    "Local outlier fraction": LocalOutlierFactor(n_neighbors=20, 
                                                 contamination=outlier_fraction)
              }

# %%
#fit the model
n_outliers = len(fraud)
for i, (clf_name, clf) in enumerate(classifiers.items()):
    if(clf_name == "Local outlier fraction"):
        y_pred = clf.fit_predict(X)
        pred_scores = clf.negative_outlier_factor_
    else:
        clf.fit(X)
        pred_scores = clf.decision_function(X)
        y_pred = clf.predict(X)
    #reset pred values
    y_pred[y_pred == 1] = 0
    y_pred[y_pred == -1] = 1
    
    n_errors = (y_pred != y).sum()
    
    #Classsification metrics
    print('{}, {}'.format(clf_name, n_errors))
    print('accuracy_score = {}'.format(accuracy_score(y, y_pred)))
    print(classification_report(y, y_pred))
# Out:
# Isolation forest, 591
# accuracy_score = 0.9976943423608998
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    255879
#            1       0.34      0.34      0.34       447
#
#     accuracy                           1.00    256326
#    macro avg       0.67      0.67      0.67    256326
# weighted avg       1.00      1.00      1.00    256326
#
# Local outlier fraction, 857
# accuracy_score = 0.9966566013592066
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    255879
#            1       0.04      0.04      0.04       447
#
#     accuracy                           1.00    256326
#    macro avg       0.52      0.52      0.52    256326
# weighted avg       1.00      1.00      1.00    256326
